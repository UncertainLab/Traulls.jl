# %%
# Load environment
using Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/.julia/dev/Traulls/benchmark`

# %%
include("../src/Traulls.jl")
using .Traulls

# %%
using Plots, BenchmarkProfiles, DataFrames, Printf, ForwardDiff

# %%
# Traulls execution

# Number of parameters for LV problems
lv_dim = [100, 500, 1000]

MAX_ITER = 500
MAX_INNER_ITER = 1000
OPT_CRIT = 1e-5
FEAS_CRIT = 1e-6


# Include problems definiton functions
# Hock Schittlowski collection
fixed_dimensions_pb = ["hs6", "hs13", "hs14", "hs16", "hs17", "hs18", "hs20", "hs22", 
"hs23", "hs26", "hs27", "hs30", "hs31", "hs32", "hs42", "hs43","hs57", "hs60", "hs61", 
"hs65", "hs70", "hs77", "hs79", "hs216", "hs227", "hs264", "hs316", "hs323", "hs337", "hs344", 
"hs345", "hs354", "hs355", "hs372", "hs373", "hs394", "hs395"]

# Luksan Vlcek
variable_dimensions_pb = ["BNST2", "BNST3", "lv501", "lv502", "lv503", "lv504", "lv511", 
"lv512", "lv513", "lv514", "lv515", "lv516", "lv517", "lv518"]

files_prefix = vcat(fixed_dimensions_pb, variable_dimensions_pb)

for prefix in files_prefix
    include("traulls_models/$(prefix).jl")
end

# First execution to compile solver
traulls(hs65())

# Dictionaries to store the results
traulls_gn = Dict{String, Traulls.TraullsResults}()
traulls_sr1_hybrid = Dict{String, Traulls.TraullsResults}()
traulls_sr1 = Dict{String, Traulls.TraullsResults}()
traulls_bfgs_hybrid = Dict{String, Traulls.TraullsResults}()
traulls_bfgs = Dict{String, Traulls.TraullsResults}()

name_instances = Vector{String}([])
# Solve problems from Hock-Schittkowski
for id in fixed_dimensions_pb
    push!(name_instances, id)
    pb = Symbol(id)
    eval(pb)()
    
    traulls_gn[id] = traulls(eval(pb)(); 
    max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
    min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

    traulls_sr1[id] = traulls(eval(pb)(); hessian_approx=:sr1, 
    max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
    min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

    traulls_bfgs[id] = traulls(eval(pb)(); hessian_approx = :bfgs,
    max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
    min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)
    
    traulls_sr1_hybrid[id] = traulls(eval(pb)(); hessian_approx=:hybrid_sr1, 
    max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
    min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

    traulls_bfgs_hybrid[id] = traulls(eval(pb)(); hessian_approx=:hybrid_bfgs, 
    max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
    min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

    @printf("\n===== %10s finished =====", id)
end

# Solve problems from Luksan-Vleck collection
for id in variable_dimensions_pb
    pb = Symbol(id)
    eval(pb)()
    
    for n in lv_dim
        id_instance = id * @sprintf("_%d", n)
        push!(name_instances, id_instance)
        
        traulls_gn[id_instance] = traulls(eval(pb)(n); hessian_approx=:gn,
        max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
        min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

        traulls_sr1[id_instance] = traulls(eval(pb)(n); hessian_approx=:sr1,
        max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
        min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)
    
        traulls_bfgs[id_instance] = traulls(eval(pb)(n); hessian_approx = :bfgs,
        max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
        min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

        traulls_sr1_hybrid[id_instance] = traulls(eval(pb)(n); hessian_approx=:hybrid_sr1,
        max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
        min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)
        
        traulls_bfgs_hybrid[id_instance] = traulls(eval(pb)(n); hessian_approx=:hybrid_bfgs,
        max_iter = MAX_ITER, max_inner_iter=MAX_INNER_ITER,
        min_reltol_crit=OPT_CRIT, min_tol_feas=FEAS_CRIT)

        @printf("\n===== %10s finished =====\n", id_instance)
    end
end
# Out:
# =====        hs6 finished =====
# =====       hs13 finished =====
# =====       hs14 finished =====
# =====       hs16 finished =====
# =====       hs17 finished =====
# =====       hs18 finished =====
# =====       hs20 finished =====
# =====       hs22 finished =====
# =====       hs23 finished =====
# =====       hs26 finished =====
# =====       hs27 finished =====
# =====       hs30 finished =====
# =====       hs31 finished =====
# =====       hs32 finished =====
# =====       hs42 finished =====
# =====       hs43 finished =====
# =====       hs57 finished =====
# =====       hs60 finished =====
# =====       hs61 finished =====
# =====       hs65 finished =====
# =====       hs70 finished =====
# =====       hs77 finished =====
# =====       hs79 finished =====
# =====      hs216 finished =====
# =====      hs227 finished =====
# =====      hs264 finished =====
# =====      hs316 finished =====
# =====      hs323 finished =====
# =====      hs337 finished =====
# =====      hs344 finished =====
# =====      hs345 finished =====
# =====      hs354 finished =====
# =====      hs355 finished =====
# =====      hs372 finished =====
# =====      hs373 finished =====
# =====      hs394 finished =====
# =====      hs395 finished =====
# =====  BNST2_100 finished =====
#
# =====  BNST2_500 finished =====
#
# ===== BNST2_1000 finished =====
#
# =====  BNST3_100 finished =====
#
# =====  BNST3_500 finished =====
#
# ===== BNST3_1000 finished =====
#
# =====  lv501_100 finished =====
#
# =====  lv501_500 finished =====
#
# ===== lv501_1000 finished =====
#
# =====  lv502_100 finished =====
#
# =====  lv502_500 finished =====
#
# ===== lv502_1000 finished =====
#
# =====  lv503_100 finished =====
#
# =====  lv503_500 finished =====
#
# ===== lv503_1000 finished =====
#
# =====  lv504_100 finished =====
#
# =====  lv504_500 finished =====
#
# ===== lv504_1000 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# =====  lv511_100 finished =====
#
# =====  lv511_500 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ===== lv511_1000 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv511.jl:6
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# =====  lv512_100 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# =====  lv512_500 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ===== lv512_1000 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv512.jl:9
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# =====  lv513_100 finished =====
#
# =====  lv513_500 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ===== lv513_1000 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv513.jl:4
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# =====  lv514_100 finished =====
#
# =====  lv514_500 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ===== lv514_1000 finished =====
# ┌ Warning: n must equal 2 modulo 3, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv514.jl:7
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# =====  lv515_100 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# =====  lv515_500 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ===== lv515_1000 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv515.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# =====  lv516_100 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# =====  lv516_500 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ===== lv516_1000 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv516.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# =====  lv517_100 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# =====  lv517_500 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ===== lv517_1000 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv517.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# =====  lv518_100 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# =====  lv518_500 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9
# ===== lv518_1000 finished =====
# ┌ Warning: number of variables must equal 1 modulo 4, rounding up
# └ @ Main ~/.julia/dev/Traulls/benchmark/traulls_models/lv518.jl:9

# %%
# Form results dataframes
nb_instances = size(name_instances, 1)

res_to_df(results) = DataFrame(name = name_instances,
    n = [size(results[pb].solution, 1) for pb in name_instances],
    elapsed_time = [results[pb].elapsed_time for pb in name_instances],
    objective = [results[pb].objective for pb in name_instances],
    neval_grad = [results[pb].counters.nalgrad_eval for pb in name_instances],
    neval_residual = [results[pb].counters.nres_eval for pb in name_instances],
    neval_jac_residual = [results[pb].counters.njacres_eval for pb in name_instances],
    nouter_iter = [results[pb].counters.niter_outer for pb in name_instances],
    ninner_iter = [results[pb].counters.niter_inner for pb in name_instances],
    status = [results[pb].status for pb in name_instances])

df_gn = res_to_df(traulls_gn)
df_bfgs = res_to_df(traulls_bfgs)
df_sr1 = res_to_df(traulls_sr1)
df_hybrid_bfgs = res_to_df(traulls_bfgs_hybrid)
df_hybrid_sr1 = res_to_df(traulls_sr1_hybrid)
# Out:
# 79×10 DataFrame
#  Row │ name        n      elapsed_time  objective       neval_grad  neval_resi ⋯
#      │ String      Int64  Float64       Float64         Int64       Int64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ hs6             2   1.59259         3.41039e-14         124             ⋯
#    2 │ hs13            3   0.000613928     0.98051              94
#    3 │ hs14            3   0.852528        1.39347              20
#    4 │ hs16            4   0.000430107     3.98206              19
#    5 │ hs17            4   0.000364065     1.0                  21             ⋯
#    6 │ hs18            4   0.00304294      5.0                 169
#    7 │ hs20            5   0.000200033    40.1987               21
#    8 │ hs22            4   0.000347137     1.0                  18
#    9 │ hs23            7   0.00202298      2.0                  26             ⋯
#   10 │ hs26            3   0.000696182     9.84895e-9           48
#   11 │ hs27            3   0.000504017     0.04                 33
#   ⋮  │     ⋮         ⋮         ⋮              ⋮             ⋮             ⋮    ⋱
#   70 │ lv515_1000   1001   0.405925        1.03297e-10          41
#   71 │ lv516_100     101   0.00581408      8.62638e-12          22             ⋯
#   72 │ lv516_500     501   0.0891781       8.61024e-13          23
#   73 │ lv516_1000   1001   0.267829        9.45726e-13          23
#   74 │ lv517_100     101   0.00698686    142.878                29
#   75 │ lv517_500     501   0.0914371     714.388                31             ⋯
#   76 │ lv517_1000   1001   0.228599     1428.78                 29
#   77 │ lv518_100     101   0.0255671     119.974                41
#   78 │ lv518_500     501   0.173548      599.868                51
#   79 │ lv518_1000   1001   0.58634      1199.74                 46             ⋯
#                                                    5 columns and 58 rows omitted

# %%
function make_traulls_table(metric, solvers)
    T = zeros(nb_instances, size(solvers,1))
    for (i, id) in enumerate(name_instances)
        for (j, df) in enumerate(solvers)
        row_id = filter(row -> row.name == id, df)
            T[i,j] = row_id[1, :status] == Traulls.:first_order_critical ? row_id[1, metric] : Inf
        end
    end

    return T
end
# Out:
# make_traulls_table (generic function with 1 method)

# %%
# Comparison of Hessian approximations
solvers_df = [df_gn, df_bfgs, df_sr1, df_hybrid_bfgs, df_hybrid_sr1]
solvers = ["Gauss-Newton", "BFGS", "SR1", "HybridBFGS", "HybridSR1"]
# Out:
# 5-element Vector{String}:
#  "Gauss-Newton"
#  "BFGS"
#  "SR1"
#  "HybridBFGS"
#  "HybridSR1"

# %%
# Show problems failures
for (i, solver) in enumerate(solvers_df)
    println("Failed instances for ", solvers[i])
    failures = filter(row -> row.status != Traulls.:first_order_critical, solver)
    println.(failures[!,:name])
end
# Out:
# Failed instances for Gauss-Newton
# Failed instances for BFGS
# lv501_500
# Failed instances for SR1
# hs373
# Failed instances for HybridBFGS
# Failed instances for HybridSR1

# %%
T = make_traulls_table(:elapsed_time, solvers_df)
plt_time = performance_profile(PlotsBackend(), T, solvers, 
        linestyles = [:solid, :solid, :solid, :dash, :dot], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "elapsed time")

T = make_traulls_table(:nouter_iter, solvers_df)
plt_nouter = performance_profile(PlotsBackend(), T, solvers, 
        linestyles = [:solid, :solid, :solid, :dash, :dot], lw=2,
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of outer iterations")

T = make_traulls_table(:ninner_iter, solvers_df)
plt_ninner = performance_profile(PlotsBackend(), T, solvers, 
        linestyles = [:solid, :solid, :solid, :dash, :dot], lw=2,
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of inner iterations");

# %%
display(plt_time)

# %%
display(plt_nouter)

# %%
display(plt_ninner)

# %%
# Comparison of Hybrid-Hessian approaches vs. Gauss-Newon
solvers_df = [df_gn, df_hybrid_bfgs, df_hybrid_sr1]
solvers = ["Gauss-Newton", "HybridBFGS", "HybridSR1"]

# Elapsed time
T = make_traulls_table(:elapsed_time, solvers_df)
plt_traulls_time = performance_profile(PlotsBackend(), T, solvers, 
        c = :black, linestyles = [:solid, :dash, :dot], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "elapsed time")

# Number of residuals evaluation
T = make_traulls_table(:neval_residual, solvers_df)
plt_traulls_neval_res = performance_profile(PlotsBackend(), T, solvers, 
        c = :black, linestyles = [:solid, :dash, :dot], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of residuals evaluations")

# Number of gradient evaluation
T = make_traulls_table(:neval_grad, solvers_df)
plt_traulls_neval_grad = performance_profile(PlotsBackend(), T, solvers, 
       c = :black, linestyles = [:solid, :dash, :dot], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of gradient evaluations");

# %%
display(plt_traulls_time)

# %%
display(plt_traulls_neval_res)

# %%
display(plt_traulls_neval_grad)

# %% [markdown]
# # Comparison against other solvers

# %%
# Running Percival.jl and Ipopt.jl
using NLPModelsIpopt, Percival, SolverBenchmark, NLSProblems

problems = [NLSProblems.hs06(), NLSProblems.hs13(), NLSProblems.hs14(), NLSProblems.hs16(), NLSProblems.hs17(), NLSProblems.hs18(),
    NLSProblems.hs20(), NLSProblems.hs22(), NLSProblems.hs23(), NLSProblems.hs26(), NLSProblems.hs27(), NLSProblems.hs30(), 
    NLSProblems.hs31(), NLSProblems.hs32(), NLSProblems.hs42(), NLSProblems.hs43(), NLSProblems.hs57(), NLSProblems.hs60(), 
    NLSProblems.hs61(), NLSProblems.hs65(), NLSProblems.hs70(), NLSProblems.hs77(), NLSProblems.hs79(), 
    tp216(), tp227(), tp264(), tp316(), tp323(), tp337(), tp344(),
    tp345(), tp354(), tp355(), tp372(), tp373(), tp394(), tp395(),
    NLSProblems.BNST2(100), NLSProblems.BNST2(500), NLSProblems.BNST2(1000),
    NLSProblems.BNST3(100), NLSProblems.BNST3(500), NLSProblems.BNST3(1000),
    LVcon501(100), LVcon501(500), LVcon501(1000),
    LVcon502(100), LVcon502(500), LVcon502(1000), 
    LVcon503(100), LVcon503(500), LVcon503(1000),
    LVcon504(100), LVcon504(500), LVcon504(1000),
    LVcon511(100), LVcon511(500), LVcon511(1000),
    LVcon512(100), LVcon512(500), LVcon512(1000),
    LVcon513(100), LVcon513(500), LVcon513(1000),
    LVcon514(100), LVcon514(500), LVcon514(1000),
    LVcon515(100), LVcon515(500), LVcon515(1000),
    LVcon516(100), LVcon516(500), LVcon516(1000),
    LVcon517(100), LVcon517(500), LVcon517(1000),
    LVcon518(100), LVcon518(500), LVcon518(1000)]

solvers = Dict(:percival => model -> percival(model; inity = true,
                                              atol=1e-5, rtol = 1e-5, ctol=1e-6, ω_min = 1e-5,
                                              max_time = 300.0, subsolver_max_iter=1000),
               :ipopt => model -> ipopt(model; tol=1e-5, max_iter = 1000, nlp_scaling_method="none",
        dual_inf_tol = Inf,
        constr_viol_tol = Inf,
        compl_inf_tol = Inf,
        acceptable_iter = 0,
        print_level=0))

stats = bmark_solvers(solvers, problems)
# Out:
# ┌ Warning: : number of variables must be of form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon511.jl:23
# ┌ Warning: : number of variables must be of form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon511.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon512.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon512.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon512.jl:23
# ┌ Warning: : number of variables must be of the form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon513.jl:23
# ┌ Warning: : number of variables must be of the form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon513.jl:23
# ┌ Warning: : number of variables must be of the form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon514.jl:23
# ┌ Warning: : number of variables must be of the form 3k + 2. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon514.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon515.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon515.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon515.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon516.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon516.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon516.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon517.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon517.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon517.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon518.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon518.jl:23
# ┌ Warning: : number of variables must be of the form 4k + 1. Rounding up
# └ @ NLSProblems ~/.julia/packages/NLSProblems/4H4Tu/src/LVcon518.jl:23
# [ Info: running solver percival
# [ Info:          Solver             Name    nvar    ncon           status    iter      Time      f(x)      Dual    Primal
# [ Info:        percival             hs06       2       1      first_order       4   9.9e-01   4.0e-27   7.6e-12   2.3e-07
# [ Info:        percival             hs13       2       1      first_order      17   2.2e-01   4.9e-01   4.5e-06   9.4e-07
# [ Info:        percival             hs14       2       2      first_order       6   3.4e-04   7.0e-01   7.3e-13   1.6e-07
# [ Info:        percival             hs16       2       2      first_order       5   3.4e-04   2.0e+00   1.1e-08   5.2e-07
# [ Info:        percival             hs17       2       2      first_order       6   5.1e-04   5.0e-01   6.2e-09   2.4e-09
# [ Info:        percival             hs18       2       2      first_order       5   6.6e-03   2.5e+00   2.1e-09   3.1e-07
# [ Info:        percival             hs20       2       3      first_order       7   2.7e-04   2.0e+01   1.6e-07   3.0e-07
# [ Info:        percival             hs22       2       2      first_order       5   1.8e-04   5.0e-01   1.3e-08   9.5e-07
# [ Info:        percival             hs23       2       5      first_order       6   6.5e-03   1.0e+00   8.6e-10   1.1e-08
# [ Info:        percival             hs26       3       1      first_order       6   1.1e-03   3.6e-11   9.5e-06   4.3e-07
# [ Info:        percival             hs27       3       1      first_order       6   2.0e-03   2.0e-02   1.0e-08   1.1e-09
# [ Info:        percival             hs30       3       1      first_order       4   3.5e-04   5.0e-01   1.3e-06   0.0e+00
# [ Info:        percival             hs31       3       1      first_order       7   1.2e-04   3.0e+00   3.1e-10   1.8e-11
# [ Info:        percival             hs32       3       2      first_order       5   4.4e-04   5.0e-01   1.3e-14   7.9e-07
# [ Info:        percival             hs42       4       2      first_order       5   9.6e-05   6.9e+00   1.1e-09   1.7e-08
# [ Info:        percival             hs43       4       3      first_order       6   5.1e-03   1.8e+01   1.3e-08   1.0e-08
# [ Info:        percival             hs57       2       1      first_order       5   3.7e-03   1.5e-02   9.3e-11   1.6e-09
# [ Info:        percival             hs60       3       1      first_order       4   6.2e-04   1.6e-02   7.5e-09   9.6e-09
# [ Info:        percival             hs61       3       2      first_order       5   8.5e-04   2.4e+01   4.2e-11   3.2e-08
# [ Info:        percival             hs65       3       1      first_order       4   5.0e-04   2.2e+01   8.7e-08   8.7e-08
# [ Info:        percival             hs70       4       1      first_order       4   3.9e-02   4.7e-03   3.6e-08   6.2e-07
# [ Info:        percival             hs77       5       2      first_order       5   4.4e-03   2.8e+00   2.5e-05   2.2e-08
# [ Info:        percival             hs79       5       3      first_order       6   1.1e-03   3.9e-02   1.1e-07   1.3e-10
# [ Info:        percival            tp216       2       1      first_order       6   3.3e-04   5.0e-01   6.9e-10   2.2e-10
# [ Info:        percival            tp227       2       2      first_order       6   3.0e-04   5.0e-01   3.2e-08   2.5e-07
# [ Info:        percival            tp264       4       3      first_order       6   4.8e-03   2.8e+01   1.4e-08   3.7e-10
# [ Info:        percival            tp316       2       1      first_order       8   1.8e-04   1.7e+02   2.3e-09   8.7e-09
# [ Info:        percival            tp323       2       2      first_order       5   1.6e-04   1.9e+00   6.3e-10   2.6e-08
# [ Info:        percival            tp337       3       1      first_order       7   1.3e-04   3.0e+00   3.1e-10   1.8e-11
# [ Info:        percival            tp344       3       1      first_order       6   2.6e-03   1.6e-02   5.0e-07   1.5e-11
# [ Info:        percival            tp345       3       1      first_order       4   1.6e-03   1.6e-02   4.3e-09   3.1e-08
# [ Info:        percival            tp354       4       1      first_order       5   2.2e-04   5.7e-02   4.6e-11   3.6e-08
# [ Info:        percival            tp355       4       1      first_order       4   2.4e-02   3.5e+01   1.5e-05   3.1e-08
# [ Info:        percival            tp372       9      12      first_order       7   9.3e-03   6.7e+03   3.4e-06   1.5e-07
# [ Info:        percival            tp373       9       6      first_order       8   7.5e-03   6.7e+03   3.4e-05   5.5e-07
# [ Info:        percival            tp394      20       1      first_order       6   2.0e-02   9.6e-01   2.4e-09   1.3e-07
# [ Info:        percival            tp395      50       1      first_order       6   8.8e-02   9.6e-01   8.2e-08   2.7e-08
# [ Info:        percival            BNST2     100      99      first_order       4   1.5e-02   4.1e-16   7.5e-10   4.1e-07
# [ Info:        percival            BNST2     500     499      first_order       6   7.9e-01   3.5e-17   8.4e-09   2.8e-09
# [ Info:        percival            BNST2    1000     999      first_order       5   6.0e+00   4.8e-17   3.0e-05   7.4e-08
# [ Info:        percival            BNST3     100      50      first_order       6   1.3e-02   4.8e-19   2.7e-09   3.6e-10
# [ Info:        percival            BNST3     500     250      first_order       6   6.6e-02   3.0e-19   6.9e-10   3.5e-09
# [ Info:        percival            BNST3    1000     500      first_order       4   4.6e-02   1.0e-16   1.5e-08   1.8e-08
# [ Info:        percival  Lukšan-Vlček 5.1     100      98      first_order       6   4.8e-02   2.8e-13   1.4e-05   2.0e-07
# [ Info:        percival  Lukšan-Vlček 5.1     500     498      first_order       6   7.9e-01   3.1e+00   2.3e-05   2.0e-07
# [ Info:        percival  Lukšan-Vlček 5.1    1000     998      first_order       6   4.8e-01   3.1e+00   1.6e-08   1.0e-07
# [ Info:        percival  Lukšan-Vlček 5.2     100      93      first_order       8   2.3e-01   1.4e+03   4.5e-09   8.6e-08
# [ Info:        percival  Lukšan-Vlček 5.2     500     493      first_order       7   3.3e+00   7.0e+03   4.3e-07   2.7e-07
# [ Info:        percival  Lukšan-Vlček 5.2    1000     993      first_order       7   7.1e+00   1.4e+04   4.3e-07   2.7e-07
# [ Info:        percival  Lukšan-Vlček 5.3     100       2      first_order       6   3.2e-02   7.1e+00   1.8e-07   2.3e-08
# [ Info:        percival  Lukšan-Vlček 5.3     500       2      first_order       6   6.8e-02   7.1e+00   1.0e-07   1.8e-09
# [ Info:        percival  Lukšan-Vlček 5.3    1000       2      first_order       6   3.4e-01   7.1e+00   2.8e-07   7.8e-09
# [ Info:        percival  Lukšan-Vlček 5.4     100      98      first_order       6   7.4e-01   8.3e+02   2.6e-04   1.6e-08
# [ Info:        percival  Lukšan-Vlček 5.4     500     498      first_order       6   3.2e+00   1.2e+03   1.6e-08   5.7e-08
# [ Info:        percival  Lukšan-Vlček 5.4    1000     998      first_order       6   1.5e+02   2.4e+03   2.0e-08   2.1e-07
# [ Info:        percival  Lukšan-Vlček 5.11     101      66      first_order       6   1.6e-01   6.4e-12   3.6e-06   1.1e-07
# [ Info:        percival  Lukšan-Vlček 5.11     500     332         max_time      26   3.0e+02   1.8e+02   9.3e+04   2.6e-07
# [ Info:        percival  Lukšan-Vlček 5.11    1001     666         max_time      16   3.0e+02   2.0e+02   1.4e+02   2.9e-05
# [ Info:        percival  Lukšan-Vlček 5.12     101      75      first_order       7   4.9e-02   7.5e+01   6.3e-06   4.5e-07
# [ Info:        percival  Lukšan-Vlček 5.12     501     375      first_order       9   2.0e+01   3.8e+02   1.8e-09   5.1e-07
# [ Info:        percival  Lukšan-Vlček 5.12    1001     750      first_order      11   6.0e+01   7.5e+02   3.5e-07   3.3e-07
# [ Info:        percival  Lukšan-Vlček 5.13     101      66      first_order       5   9.2e-02   3.8e+02   2.2e-07   8.4e-08
# [ Info:        percival  Lukšan-Vlček 5.13     500     332      first_order       6   6.5e-01   2.0e+03   6.6e-05   4.5e-09
# [ Info:        percival  Lukšan-Vlček 5.13    1001     666      first_order       6   1.6e+00   4.0e+03   9.6e-08   2.0e-08
# [ Info:        percival  Lukšan-Vlček 5.14     101      66      first_order       7   2.4e-01   2.6e+02   1.3e-06   1.3e-07
# [ Info:        percival  Lukšan-Vlček 5.14     500     332      first_order       8   2.4e+00   1.3e+03   5.6e-05   7.0e-11
# [ Info:        percival  Lukšan-Vlček 5.14    1001     666      first_order       7   8.4e+00   2.6e+03   1.4e+00   8.1e-07
# [ Info:        percival  Lukšan-Vlček 5.15     101      75      first_order       7   6.9e-01   7.3e-16   2.2e-09   2.1e-07
# [ Info:        percival  Lukšan-Vlček 5.15     501     375      first_order       7   5.0e+00   1.5e-07   3.6e-01   8.7e-07
# [ Info:        percival  Lukšan-Vlček 5.15    1001     750      first_order       8   1.7e+01   3.9e-16   4.6e-04   1.5e-07
# [ Info:        percival  Lukšan-Vlček 5.16     101      75      first_order       6   8.1e-02   7.5e-13   6.0e-07   2.6e-07
# [ Info:        percival  Lukšan-Vlček 5.16     501     375      first_order       7   7.9e+00   3.0e+04   2.1e-05   2.2e-08
# [ Info:        percival  Lukšan-Vlček 5.16    1001     750      first_order       7   3.0e+01   6.3e+04   2.6e-05   2.4e-08
# [ Info:        percival  Lukšan-Vlček 5.17     101      75      first_order       7   1.7e-02   7.1e+01   9.3e-08   3.9e-09
# [ Info:        percival  Lukšan-Vlček 5.17     501     375      first_order       6   6.0e-02   3.6e+02   8.5e-11   4.1e-07
# [ Info:        percival  Lukšan-Vlček 5.17    1001     750      first_order       6   1.3e-01   7.1e+02   1.7e-09   5.9e-07
# [ Info:        percival  Lukšan-Vlček 5.18     101      75      first_order       6   3.0e-02   6.0e+01   7.3e-06   4.0e-07
# [ Info:        percival  Lukšan-Vlček 5.18     501     375      first_order       6   1.3e-01   3.0e+02   2.8e-09   1.7e-08
# [ Info:        percival  Lukšan-Vlček 5.18    1001     750      first_order       6   2.4e+00   6.0e+02   6.3e-10   9.9e-09
# [ Info: running solver ipopt
# [ Info:          Solver             Name    nvar    ncon           status    iter      Time      f(x)      Dual    Primal
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
# [ Info:           ipopt             hs06       2       1      first_order       1   7.2e+00   0.0e+00   0.0e+00   2.0e-14
# [ Info:           ipopt             hs13       2       1      first_order      41   1.5e-02   5.0e-01   9.9e-05   2.0e-12
# [ Info:           ipopt             hs14       2       2      first_order       5   1.9e-03   7.0e-01   9.7e-07   3.1e-07
# [ Info:           ipopt             hs16       2       2      first_order      10   9.2e-02   2.0e+00   1.9e-08   5.4e-10
# [ Info:           ipopt             hs17       2       2      first_order      11   6.1e-03   5.0e-01   1.9e-11   5.3e-08
# [ Info:           ipopt             hs18       2       2      first_order      14   8.1e-03   2.5e+00   1.1e-08   8.2e-07
# [ Info:           ipopt             hs20       2       3      first_order       6   4.2e-03   2.0e+01   4.4e-10   2.4e-11
# [ Info:           ipopt             hs22       2       2      first_order       5   3.8e-03   5.0e-01   7.7e-08   1.3e-07
# [ Info:           ipopt             hs23       2       5      first_order       9   4.7e-03   1.0e+00   4.4e-07   1.9e-07
# [ Info:           ipopt             hs26       3       1      first_order      11   6.6e-03   4.5e-16   6.4e-11   2.7e-06
# [ Info:           ipopt             hs27       3       1         max_iter    1000   4.3e-01   1.1e-02   1.5e-01   8.5e-01
# [ Info:           ipopt             hs30       3       1      first_order       6   2.3e-03   5.0e-01   8.4e-07   1.4e-07
# [ Info:           ipopt             hs31       3       1      first_order       6   2.7e-03   3.0e+00   1.5e-08   1.8e-10
# [ Info:           ipopt             hs32       3       2      first_order       9   2.7e-03   5.0e-01   9.1e-12   2.5e-09
# [ Info:           ipopt             hs42       4       2      first_order       5   2.3e-03   6.9e+00   1.3e-10   2.6e-11
# [ Info:           ipopt             hs43       4       3      first_order       8   3.2e-03   1.8e+01   1.9e-07   1.2e-07
# [ Info:           ipopt             hs57       2       1      first_order      14   1.4e-02   5.8e-02   8.9e-06   7.1e-08
# [ Info:           ipopt             hs60       3       1      first_order       5   3.9e-03   1.6e-02   3.1e-11   1.2e-10
# [ Info:           ipopt             hs61       3       2      first_order       8   3.4e-03   2.4e+01   3.9e-08   3.4e-08
# [ Info:           ipopt             hs65       3       1      first_order      11   4.1e-03   2.2e+01   4.4e-09   2.8e-09
# [ Info:           ipopt             hs70       4       1          unknown      34   3.7e-02   8.8e-02   2.3e-05   7.8e-08
# [ Info:           ipopt             hs77       5       2      first_order       8   3.6e-03   1.2e-01   2.2e-06   9.0e-06
# [ Info:           ipopt             hs79       5       3      first_order       4   2.8e-03   3.9e-02   3.8e-09   9.0e-09
# [ Info:           ipopt            tp216       2       1      first_order      10   6.2e-03   5.0e-01   3.6e-13   9.8e-13
# [ Info:           ipopt            tp227       2       2      first_order       5   2.3e-03   5.0e-01   5.6e-07   1.6e-07
# [ Info:           ipopt            tp264       4       3      first_order       8   4.9e-03   2.8e+01   5.0e-07   5.6e-07
# [ Info:           ipopt            tp316       2       1      first_order       7   5.5e-03   1.7e+02   1.5e-10   2.2e-16
# [ Info:           ipopt            tp323       2       2      first_order       6   3.2e-03   1.9e+00   2.6e-08   4.8e-09
# [ Info:           ipopt            tp337       3       1      first_order       6   5.0e-03   3.0e+00   1.7e-08   3.2e-10
# [ Info:           ipopt            tp344       3       1      first_order       5   2.7e-03   1.6e-02   3.6e-09   1.3e-08
# [ Info:           ipopt            tp345       3       1      first_order       9   4.4e-03   1.6e-02   6.5e-07   6.0e-06
# [ Info:           ipopt            tp354       4       1      first_order       7   4.6e-03   5.7e-02   1.5e-09   4.6e-10
# [ Info:           ipopt            tp355       4       1      first_order      40   2.2e-02   3.5e+01   4.7e-08   6.5e-08
# [ Info:           ipopt            tp372       9      12      first_order      28   1.6e-02   6.7e+03   1.8e-11   1.1e-13
# [ Info:           ipopt            tp373       9       6      first_order       3   2.8e-03   6.7e+03   1.8e-11   6.4e-13
# [ Info:           ipopt            tp394      20       1      first_order      13   8.3e-03   9.6e-01   1.5e-09   3.0e-09
# [ Info:           ipopt            tp395      50       1      first_order      20   2.1e-02   9.6e-01   1.4e-09   8.8e-10
# [ Info:           ipopt            BNST2     100      99      first_order       2   3.2e-03   1.9e-12   3.1e-06   2.8e-06
# [ Info:           ipopt            BNST2     500     499      first_order       2   1.0e-02   5.3e-12   2.0e-06   1.8e-06
# [ Info:           ipopt            BNST2    1000     999      first_order       2   2.1e-02   4.8e-12   1.2e-06   1.1e-06
# [ Info:           ipopt            BNST3     100      50      first_order       2   4.5e-03   2.5e-13   1.0e-07   9.1e-08
# [ Info:           ipopt            BNST3     500     250      first_order       2   9.3e-03   1.3e-12   1.0e-07   9.1e-08
# [ Info:           ipopt            BNST3    1000     500      first_order       2   1.8e-02   2.5e-12   1.0e-07   9.1e-08
# [ Info:           ipopt  Lukšan-Vlček 5.1     100      98      first_order       6   1.5e-02   3.1e+00   1.6e-08   4.9e-11
# [ Info:           ipopt  Lukšan-Vlček 5.1     500     498      first_order       6   7.7e-02   3.1e+00   1.6e-08   4.9e-11
# [ Info:           ipopt  Lukšan-Vlček 5.1    1000     998      first_order       6   9.3e-02   3.1e+00   1.6e-08   4.9e-11
# [ Info:           ipopt  Lukšan-Vlček 5.2     100      93      first_order      31   9.8e-02   1.4e+03   1.3e-09   3.5e-12
# [ Info:           ipopt  Lukšan-Vlček 5.2     500     493      first_order      34   4.1e-01   7.0e+03   1.2e-06   5.8e-09
# [ Info:           ipopt  Lukšan-Vlček 5.2    1000     993      first_order      28   9.0e-01   1.4e+04   3.7e-09   4.7e-11
# [ Info:           ipopt  Lukšan-Vlček 5.3     100       2      first_order       8   3.6e-02   7.1e+00   7.4e-10   1.1e-09
# [ Info:           ipopt  Lukšan-Vlček 5.3     500       2      first_order       8   7.3e-02   7.1e+00   7.4e-10   1.1e-09
# [ Info:           ipopt  Lukšan-Vlček 5.3    1000       2      first_order       8   8.5e-02   7.1e+00   7.4e-10   1.1e-09
# [ Info:           ipopt  Lukšan-Vlček 5.4     100      98      first_order      53   1.2e-01   2.3e+02   2.6e-08   8.4e-09
# [ Info:           ipopt  Lukšan-Vlček 5.4     500     498      first_order      88   1.7e+00   1.2e+03   1.4e-06   3.2e-07
# [ Info:           ipopt  Lukšan-Vlček 5.4    1000     998      first_order      51   1.8e+00   2.4e+03   8.4e-07   4.8e-06
# [ Info:           ipopt  Lukšan-Vlček 5.11     101      66      first_order      14   1.7e-02   3.2e-16   6.9e-09   1.7e-08
# [ Info:           ipopt  Lukšan-Vlček 5.11     500     332      first_order      44   2.2e-01   7.0e-15   3.0e-08   4.0e-08
# [ Info:           ipopt  Lukšan-Vlček 5.11    1001     666      first_order      44   3.8e-01   6.9e-15   3.0e-08   3.9e-08
# [ Info:           ipopt  Lukšan-Vlček 5.12     101      75      first_order       8   9.9e-03   7.5e+01   1.1e-06   2.3e-07
# [ Info:           ipopt  Lukšan-Vlček 5.12     501     375      first_order       9   4.1e-02   3.8e+02   4.2e-12   3.9e-12
# [ Info:           ipopt  Lukšan-Vlček 5.12    1001     750      first_order       8   6.1e-02   7.5e+02   5.5e-06   3.5e-07
# [ Info:           ipopt  Lukšan-Vlček 5.13     101      66      first_order      13   9.4e-03   3.8e+02   1.7e-07   9.9e-06
# [ Info:           ipopt  Lukšan-Vlček 5.13     500     332      first_order      13   3.8e-02   2.0e+03   1.7e-07   9.9e-06
# [ Info:           ipopt  Lukšan-Vlček 5.13    1001     666      first_order      13   7.2e-02   4.0e+03   1.7e-07   9.9e-06
# [ Info:           ipopt  Lukšan-Vlček 5.14     101      66      first_order      13   9.9e-03   2.6e+02   1.5e-08   2.4e-09
# [ Info:           ipopt  Lukšan-Vlček 5.14     500     332      first_order      13   4.4e-02   1.3e+03   2.9e-09   9.0e-10
# [ Info:           ipopt  Lukšan-Vlček 5.14    1001     666      first_order      13   1.3e-01   2.6e+03   2.9e-09   9.0e-10
# [ Info:           ipopt  Lukšan-Vlček 5.15     101      75      first_order      25   2.4e-02   1.9e-20   2.0e-10   1.5e-10
# [ Info:           ipopt  Lukšan-Vlček 5.15     501     375      first_order      25   7.8e-02   1.9e-20   2.0e-10   1.5e-10
# [ Info:           ipopt  Lukšan-Vlček 5.15    1001     750      first_order      25   1.7e-01   1.9e-20   2.0e-10   1.5e-10
# [ Info:           ipopt  Lukšan-Vlček 5.16     101      75      first_order       7   6.0e-03   5.0e-15   1.8e-07   1.5e-08
# [ Info:           ipopt  Lukšan-Vlček 5.16     501     375      first_order       7   2.6e-02   5.0e-15   1.8e-07   1.5e-08
# [ Info:           ipopt  Lukšan-Vlček 5.16    1001     750      first_order       7   4.5e-02   5.0e-15   1.8e-07   1.5e-08
# [ Info:           ipopt  Lukšan-Vlček 5.17     101      75      first_order      10   6.6e-03   7.1e+01   1.8e-10   6.4e-11
# [ Info:           ipopt  Lukšan-Vlček 5.17     501     375      first_order      10   2.3e-02   3.6e+02   1.8e-10   6.4e-11
# [ Info:           ipopt  Lukšan-Vlček 5.17    1001     750      first_order      10   1.2e-01   7.1e+02   1.8e-10   6.4e-11
# [ Info:           ipopt  Lukšan-Vlček 5.18     101      75      first_order       8   5.5e-03   6.0e+01   9.4e-07   1.3e-07
# [ Info:           ipopt  Lukšan-Vlček 5.18     501     375      first_order       8   2.1e-02   3.0e+02   9.4e-07   1.3e-07
# [ Info:           ipopt  Lukšan-Vlček 5.18    1001     750      first_order       8   4.8e-02   6.0e+02   9.4e-07   1.3e-07
# Dict{Symbol, DataFrame} with 2 entries:
#   :percival => 79×40 DataFrame…
#   :ipopt    => 79×41 DataFrame…

# %%
# Allign name instances
for solver in keys(solvers)
    stats[solver][!, :name] .= name_instances
end

# %%
# Insert number of gradient evaluations for Ipopt
# Equals the number of jacobian evaluation minus 1
stats[:ipopt][!, :neval_grad] .= stats[:ipopt][!, :neval_jac_residual] .- 1
# Out:
# 79-element Vector{Int64}:
#     1
#    41
#     5
#    10
#    11
#    14
#     6
#     5
#     9
#    11
#  1060
#     6
#     6
#     ⋮
#    25
#    25
#    25
#     7
#     7
#     7
#    10
#    10
#    10
#     8
#     8
#     8

# %%
solvers = ["Traulls.jl", "Ipopt.jl", "Percival.jl"]

function make_performance_table(stats_traulls, stats_ipopt, stats_percival, name_instances, metric)

    nb_instances = size(name_instances, 1)
    T = zeros(nb_instances, 3)

    for (i, pb) in enumerate(name_instances)
        row_traulls = filter(row -> row.name == pb, stats_traulls)
        T[i, 1] = row_traulls[1, :status] == Traulls.:first_order_critical ? row_traulls[1, metric] : Inf
        
        row_ipopt = filter(row -> row.name == pb, stats_ipopt)
        T[i, 2] = row_ipopt[1, :internal_msg] == :Solve_Succeeded ? row_ipopt[1, metric] : Inf
        
        row_percival = filter(row -> row.name == pb, stats_percival)
        T[i, 3] = row_percival[1, :status] == :first_order ? row_percival[1, metric] : Inf
    end

    return T
end

performance_table(metric) = make_performance_table(df_hybrid_sr1, stats[:ipopt], stats[:percival], name_instances, metric)
# Out:
# performance_table (generic function with 1 method)

# %%
# Elapsed time
T = performance_table(:elapsed_time)
plt_elapsed_time = performance_profile(PlotsBackend(), T, solvers, 
        c = :black, linestyles = [:dot, :solid, :dash], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "elapsed time")

# Residual evaluation
T = performance_table(:neval_residual)
plt_neval_res = performance_profile(PlotsBackend(), T, solvers, 
        c = :black, linestyles = [:dot, :solid, :dash], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of residuals evaluations")

# Gradient evaluations
T = performance_table(:neval_grad)
plt_neval_grad = performance_profile(PlotsBackend(), T, solvers, 
        c = :black, linestyles = [:dot, :solid, :dash], lw=2, 
    legend=:bottomright, xaxis = "τ (logscale)", yaxis = "ρ(τ)", title = "number of gradient evaluations");

# %%
display(plt_elapsed_time)

# %%
display(plt_neval_res)

# %%
display(plt_neval_grad)
